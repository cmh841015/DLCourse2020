# %%
import pandas as pd
import numpy as ny
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2454.TW.csv',index_col='Date')

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close       Volume
# Date
# 2001-07-23  72.471001  72.471001  72.471001  72.471001  35.669979     463096.0
# 2001-07-24  76.625504  77.352501  75.161797  77.106903  37.951759  238341537.0
# 2001-07-25  77.106903  82.480499  77.106903  82.480499  40.596626   94092604.0
# 2001-07-26  85.407997  88.089897  84.671204  88.089897  43.357555   64114299.0
# 2001-07-27  90.290398  91.754204  87.353104  87.844299  43.236660   60369076.0

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4add252522c8> in <module>
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
21502 * 1000 #上面Volume應該是股數
# Out:
# 21502000

# %%
#!pip install TA-Lib

# %%
#from talib import abstract   # abstract  是 talib 裡面計算指標用的

# %%
import talib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-1ee486ccef90> in <module>
# ----> 1 import talib
#
# ModuleNotFoundError: No module named 'talib'

# %%
#df.set_axis(["open","high","low","close","adj","volume"], axis=1, inplace=True) #因為Talib要小寫

# %%
sma = talib.SMA(df["Close"][-3000:],60)

# %%
ma = df["Close"][-3000:].rolling(60).mean()

# %%
sma
# Out:
# Date
# 2008-06-24   NaN
# 2008-06-25   NaN
# 2008-06-26   NaN
# 2008-06-27   NaN
# 2008-06-30   NaN
#               ..
# 2020-08-17   NaN
# 2020-08-18   NaN
# 2020-08-19   NaN
# 2020-08-20   NaN
# 2020-08-21   NaN
# Length: 3000, dtype: float64

# %%
sma.dropna()
# Out:
# Date
# 2008-09-15    327.898848
# 2008-09-16    327.893265
# 2008-09-17    327.783966
# 2008-09-18    327.513615
# 2008-09-19    327.594016
#                  ...
# 2016-01-25    252.700000
# 2016-01-26    251.683333
# 2016-01-27    250.600000
# 2016-01-28    249.025000
# 2016-01-29    247.641667
# Length: 1829, dtype: float64

# %%
ma
# Out:
# Date
# 2008-06-24           NaN
# 2008-06-25           NaN
# 2008-06-26           NaN
# 2008-06-27           NaN
# 2008-06-30           NaN
#                  ...
# 2020-08-17    591.225000
# 2020-08-18    594.141667
# 2020-08-19    596.625000
# 2020-08-20    598.375000
# 2020-08-21    600.700000
# Name: Close, Length: 3000, dtype: float64

# %%
#為什麼talib後面是nan???
#所以資料庫很重要 網路上的資料不可信XD

# %%
#2016-1-30是na
df.dropna(inplace=True)

# %%
sma = talib.SMA(df["Close"][-3000:],60)

# %%
sma
# Out:
# Date
# 2008-06-17           NaN
# 2008-06-18           NaN
# 2008-06-19           NaN
# 2008-06-20           NaN
# 2008-06-23           NaN
#                  ...
# 2020-08-17    591.225000
# 2020-08-18    594.141667
# 2020-08-19    596.625000
# 2020-08-20    598.375000
# 2020-08-21    600.700000
# Length: 3000, dtype: float64

# %%
ma = df["Close"][-3000:].rolling(60).mean()
ma
# Out:
# Date
# 2008-06-17           NaN
# 2008-06-18           NaN
# 2008-06-19           NaN
# 2008-06-20           NaN
# 2008-06-23           NaN
#                  ...
# 2020-08-17    591.225000
# 2020-08-18    594.141667
# 2020-08-19    596.625000
# 2020-08-20    598.375000
# 2020-08-21    600.700000
# Name: Close, Length: 3000, dtype: float64

# %% [markdown]
# # 製作Features

# %%
sma_60 = talib.SMA(df["Close"],60)
sma_20 = talib.SMA(df["Close"],20)
sma_5 = talib.SMA(df["Close"],5)

# %%
sma_60
# Out:
# Date
# 2001-07-23           NaN
# 2001-07-24           NaN
# 2001-07-25           NaN
# 2001-07-26           NaN
# 2001-07-27           NaN
#                  ...
# 2020-08-17    591.225000
# 2020-08-18    594.141667
# 2020-08-19    596.625000
# 2020-08-20    598.375000
# 2020-08-21    600.700000
# Length: 4762, dtype: float64

# %%
rsi = talib.RSI(df["Close"],14)

# %%
sma_60
# Out:
# Date
# 2001-07-23           NaN
# 2001-07-24           NaN
# 2001-07-25           NaN
# 2001-07-26           NaN
# 2001-07-27           NaN
#                  ...
# 2020-08-17    591.225000
# 2020-08-18    594.141667
# 2020-08-19    596.625000
# 2020-08-20    598.375000
# 2020-08-21    600.700000
# Length: 4762, dtype: float64

# %%
rsi.plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
k, d = talib.STOCH  (df["High"], df["Low"], df["Close"], fastk_period=120, slowk_period=60, slowd_period=60)

# %%
k
# Out:
# Date
# 2001-07-23          NaN
# 2001-07-24          NaN
# 2001-07-25          NaN
# 2001-07-26          NaN
# 2001-07-27          NaN
#                 ...
# 2020-08-17    91.666219
# 2020-08-18    91.468973
# 2020-08-19    91.098885
# 2020-08-20    90.579138
# 2020-08-21    90.155635
# Length: 4762, dtype: float64

# %%
d
# Out:
# Date
# 2001-07-23          NaN
# 2001-07-24          NaN
# 2001-07-25          NaN
# 2001-07-26          NaN
# 2001-07-27          NaN
#                 ...
# 2020-08-17    74.513389
# 2020-08-18    75.325665
# 2020-08-19    76.115780
# 2020-08-20    76.880481
# 2020-08-21    77.616203
# Length: 4762, dtype: float64

# %% [markdown]
# # 製作DataSet

# %%
dataset = pd.DataFrame({
        'sma_60': sma_60,
        'sma_20': sma_20,
        'sma_5': sma_5,
        'k':k,
        'd':d,
        'rsi':rsi
    })

# %%
dataset
# Out:
#                 sma_60  sma_20      sma_5          k          d        rsi
# Date
# 2001-07-23         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-24         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-25         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-26         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-27         NaN     NaN   81.59852        NaN        NaN        NaN
# ...                ...     ...        ...        ...        ...        ...
# 2020-08-17  591.225000  692.50  684.40000  91.666219  74.513389  55.524987
# 2020-08-18  594.141667  691.50  669.20000  91.468973  75.325665  39.190404
# 2020-08-19  596.625000  688.75  655.00000  91.098885  76.115780  37.782178
# 2020-08-20  598.375000  683.15  631.20000  90.579138  76.880481  31.151991
# 2020-08-21  600.700000  679.60  616.00000  90.155635  77.616203  41.029944
#
# [4762 rows x 6 columns]

# %%
usefeatures = dataset.columns

# %%
usefeatures
# Out:
# Index(['sma_60', 'sma_20', 'sma_5', 'k', 'd', 'rsi'], dtype='object')

# %%
dataset["Return"] = (df["Close"].shift(-3) / df["Close"] ) > 1

# %%
dataset["Price"] = df["Close"]

# %%
dataset
# Out:
#                 sma_60  sma_20      sma_5          k          d        rsi  \
# Date
# 2001-07-23         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-24         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-25         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-26         NaN     NaN        NaN        NaN        NaN        NaN
# 2001-07-27         NaN     NaN   81.59852        NaN        NaN        NaN
# ...                ...     ...        ...        ...        ...        ...
# 2020-08-17  591.225000  692.50  684.40000  91.666219  74.513389  55.524987
# 2020-08-18  594.141667  691.50  669.20000  91.468973  75.325665  39.190404
# 2020-08-19  596.625000  688.75  655.00000  91.098885  76.115780  37.782178
# 2020-08-20  598.375000  683.15  631.20000  90.579138  76.880481  31.151991
# 2020-08-21  600.700000  679.60  616.00000  90.155635  77.616203  41.029944
#
#             Return       Price
# Date
# 2001-07-23    True   72.471001
# 2001-07-24    True   77.106903
# 2001-07-25    True   82.480499
# 2001-07-26    True   88.089897
# 2001-07-27    True   87.844299
# ...            ...         ...
# 2020-08-17   False  685.000000
# 2020-08-18   False  617.000000
# 2020-08-19   False  609.000000
# 2020-08-20   False  565.000000
# 2020-08-21   False  604.000000
#
# [4762 rows x 8 columns]

# %% [markdown]
# # 準備訓練資料跟測試資料

# %%
#filter na
print("before dropping NaN", dataset.shape)
dataset.dropna(inplace=True)
print("after dropping NaN", dataset.shape)
# Out:
# before dropping NaN (4762, 8)
# after dropping NaN (4525, 8)

# %%
dataset[1000:2000]
# Out:
#                 sma_60      sma_20       sma_5          k          d  \
# Date
# 2006-05-02  297.467133  314.465698  312.683405  59.498084  61.547499
# 2006-05-03  298.131149  314.507648  311.089801  59.875516  61.304501
# 2006-05-04  298.746216  314.633447  312.934998  60.223915  61.075592
# 2006-05-05  299.389249  314.717348  315.367395  60.606631  60.861659
# 2006-05-08  300.416699  316.122198  321.406195  61.401999  60.667637
# ...                ...         ...         ...        ...        ...
# 2010-05-06  526.748397  538.039200  523.725391  58.968921  67.143272
# 2010-05-07  527.254931  536.666651  522.744995  59.055372  66.746383
# 2010-05-10  527.647082  535.833301  521.764600  59.026594  66.359811
# 2010-05-11  527.794131  534.852899  518.627197  58.767972  65.980275
# 2010-05-12  527.973881  533.431351  516.078198  58.522244  65.607916
#
#                   rsi  Return       Price
# Date
# 2006-05-02  50.073438    True  310.334991
# 2006-05-03  54.064933    True  315.786987
# 2006-05-04  55.536664    True  317.882996
# 2006-05-05  57.305667    True  320.399994
# 2006-05-08  69.024968    True  342.626007
# ...               ...     ...         ...
# 2010-05-06  40.423338   False  513.724976
# 2010-05-07  42.874381   False  518.627014
# 2010-05-10  44.830038   False  522.549011
# 2010-05-11  41.396294    True  513.724976
# 2010-05-12  40.651493   False  511.765015
#
# [1000 rows x 8 columns]

# %%
dataset.index
# Out:
# Index(['2002-06-19', '2002-06-20', '2002-06-21', '2002-06-24', '2002-06-25',
#        '2002-06-26', '2002-06-27', '2002-06-28', '2002-07-01', '2002-07-02',
#        ...
#        '2020-08-10', '2020-08-11', '2020-08-12', '2020-08-13', '2020-08-14',
#        '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20', '2020-08-21'],
#       dtype='object', name='Date', length=4525)

# %%
dataset_train = dataset[:'2016']
dataset_test = dataset['2016':]
train_price = dataset["Price"][:'2016']
test_price = dataset["Price"]['2016':]
train_x = dataset_train[usefeatures]
train_y = dataset_train['Return']
test_x = dataset_test[usefeatures]
test_y = dataset_test['Return']

# %%
train_x #注意要沒有拿到price!!
# Out:
#                 sma_60      sma_20       sma_5          k          d  \
# Date
# 2002-06-19  202.883783  164.559151  152.158603  48.282006  78.448562
# 2002-06-20  201.039049  163.312051  152.227402  46.792790  77.709663
# 2002-06-21  199.359516  161.928901  153.390600  45.416323  76.947186
# 2002-06-24  197.719766  160.784901  154.962399  44.068558  76.162122
# 2002-06-25  195.983249  159.674850  155.919400  42.679049  75.354269
# ...                ...         ...         ...        ...        ...
# 2015-12-25  266.466667  261.375000  256.500000  18.780510  14.600302
# 2015-12-28  266.633333  261.325000  257.600000  18.917141  14.772837
# 2015-12-29  266.750000  260.775000  255.500000  19.013231  14.951676
# 2015-12-30  266.808333  259.750000  253.800000  19.079184  15.135657
# 2015-12-31  266.675000  258.550000  252.900000  19.090753  15.320375
#
#                   rsi
# Date
# 2002-06-19  31.738284
# 2002-06-20  35.979458
# 2002-06-21  41.670005
# 2002-06-24  43.363226
# 2002-06-25  42.048730
# ...               ...
# 2015-12-25  45.609419
# 2015-12-28  48.153071
# 2015-12-29  41.529691
# 2015-12-30  40.580560
# 2015-12-31  42.007879
#
# [3398 rows x 6 columns]

# %%
test_x
# Out:
#                 sma_60   sma_20  sma_5          k          d        rsi
# Date
# 2016-01-04  266.333333  257.350  250.6  18.990812  15.499793  38.673116
# 2016-01-05  265.933333  255.725  247.2  18.862295  15.672505  37.087785
# 2016-01-06  265.100000  253.575  242.6  18.549774  15.833960  29.117971
# 2016-01-07  263.991667  250.675  234.1  18.203876  15.985428  22.167596
# 2016-01-08  262.950000  248.350  226.8  17.945659  16.129639  28.712277
# ...                ...      ...    ...        ...        ...        ...
# 2020-08-17  591.225000  692.500  684.4  91.666219  74.513389  55.524987
# 2020-08-18  594.141667  691.500  669.2  91.468973  75.325665  39.190404
# 2020-08-19  596.625000  688.750  655.0  91.098885  76.115780  37.782178
# 2020-08-20  598.375000  683.150  631.2  90.579138  76.880481  31.151991
# 2020-08-21  600.700000  679.600  616.0  90.155635  77.616203  41.029944
#
# [1127 rows x 6 columns]

# %% [markdown]
# # 準備模型

# %%
import keras.layers as layers
from keras.models import Sequential
import keras

# %%
model = Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(len(usefeatures),)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer="adam")

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 100)               700
# _________________________________________________________________
# dense_23 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_x,train_y)
# Out:
# Epoch 1/1
# 3398/3398 [==============================] - 1s 149us/step - loss: 2.3053

# %%
exp_y = model.predict(train_x[usefeatures])

# %%
exp_y[0:3]
# Out:
# array([[0.96634126],
#        [0.96591747],
#        [0.968544  ]], dtype=float32)

# %%
exp_y.shape
# Out:
# (3398, 1)

# %%
#要知道這些預測值對應哪些天：弄成dataframe
pd.Series(exp_y,train_x.index)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-501-345acd595cb3> in <module>
#       1 #要知道這些預測值對應哪些天：弄成dataframe
# ----> 2 pd.Series(exp_y,train_x.index)
#
# ~/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# ~/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     490     elif subarr.ndim > 1:
#     491         if isinstance(data, np.ndarray):
# --> 492             raise Exception("Data must be 1-dimensional")
#     493         else:
#     494             subarr = com.asarray_tuplesafe(data, dtype=dtype)
#
# Exception: Data must be 1-dimensional

# %%
#exp_y = exp_y.swapaxes(0, 1)[0]

# %%
#或用reshape
exp_y = exp_y.reshape(3398,)

# %%
exp_y.shape
# Out:
# (3398,)

# %%
#比較
df["Close"].shape
# Out:
# (4762,)

# %%
exp_y = pd.Series(exp_y, index=train_x.index)

# %%
exp_y
# Out:
# Date
# 2002-06-19    0.966341
# 2002-06-20    0.965917
# 2002-06-21    0.968544
# 2002-06-24    0.970038
# 2002-06-25    0.970929
#                 ...
# 2015-12-25    0.922403
# 2015-12-28    0.920836
# 2015-12-29    0.924743
# 2015-12-30    0.924804
# 2015-12-31    0.921684
# Length: 3398, dtype: float32

# %%
exp_y.plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
exp_y.hist()
# Out:
# <AxesSubplot:>

# %%
hold = (exp_y > exp_y.quantile(0.6)).rolling(3).sum() > 0 
#exp_y 比自己PR 60的人還要大 
#rolling 3 代表連續看三天
#sum>0 代表有一天>0就持有 一持有就是要抱三天
#注意括號位置

# %%
hold
# Out:
# Date
# 2002-06-19    False
# 2002-06-20    False
# 2002-06-21    False
# 2002-06-24    False
# 2002-06-25    False
#               ...
# 2015-12-25    False
# 2015-12-28    False
# 2015-12-29    False
# 2015-12-30    False
# 2015-12-31    False
# Length: 3398, dtype: bool

# %%
returns = train_price.shift(-1) - train_price

# %%
train_price.plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
returns.cumsum().plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
returns
# Out:
# Date
# 2002-06-19     3.752991
# 2002-06-20     5.472000
# 2002-06-21     1.709000
# 2002-06-24    -1.709000
# 2002-06-25   -10.934005
#                 ...
# 2015-12-25     3.000000
# 2015-12-28    -9.500000
# 2015-12-29    -1.500000
# 2015-12-30     1.500000
# 2015-12-31          NaN
# Name: Price, Length: 3398, dtype: float64

# %%
returns[hold==True].cumsum().plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
returns[hold==True].cumsum()
# Out:
# Date
# 2003-09-08      9.686004
# 2003-09-09      9.686004
# 2003-09-10      9.686004
# 2003-09-11      6.453994
# 2003-09-12      5.166992
#                  ...
# 2015-10-02   -142.951021
# 2015-10-05   -140.951021
# 2015-10-06   -127.951021
# 2015-10-07   -120.451021
# 2015-10-08   -119.451021
# Name: Price, Length: 1397, dtype: float64

# %%
hold
# Out:
# Date
# 2002-06-19    False
# 2002-06-20    False
# 2002-06-21    False
# 2002-06-24    False
# 2002-06-25    False
#               ...
# 2015-12-25    False
# 2015-12-28    False
# 2015-12-29    False
# 2015-12-30    False
# 2015-12-31    False
# Length: 3398, dtype: bool

# %%
#手續費
(hold.astype(int).diff().abs().fillna(0) * 3).sum()
# Out:
# 102.0

# %%
#跟傻瓜比
hold_count = hold.sum()
print(hold_count)
print(len(returns))
# Out:
# 1397
# 3398

# %%
import numpy as np;
samples=[];
for i in range(1000):
  ret = np.random.choice(returns.dropna(),hold_count).sum();
  #print(ret)
  samples.append(ret)

#samples.hist()
pd.Series(samples).hist()
# Out:
# <AxesSubplot:>

# %%
(pd.Series(samples)>950).sum() / len(samples) #賺超過950塊佔傻瓜的比重 0.3%
# Out:
# 0.001

# %%
#下面function寫好再回來測試
showResult(train_price,exp_y,0.6)
plt.show()
showRandomResult(train_price,exp_y)
# Out:
# final -119.45102099999997 and fee: 102.0
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# # 練習:把上面兩段分析變成function

# %%
#待改
def showResult(prices,predicts,threshhold=0.7):
    change = (prices.shift(-1) - prices)
    signal = (predicts > predicts.quantile(threshhold)).rolling(3).sum() > 0
    profit = (change[signal]).cumsum()
    fee = (signal.astype(int).diff().abs().fillna(0) * 3).sum()
    print("final" , profit[-1] , "and fee:" , fee)
    profit.plot()

# %%
import numpy as np;

def showRandomResult(prices,predicts,threshhold=0.7):
    samples=[];
    cumReturn = (prices.shift(-1) - prices)
    signal = (predicts > predicts.quantile(threshhold)).rolling(3).sum() > 0
    holds_count = signal.sum()
    for i in range(1000):
      ret = np.random.choice(cumReturn.dropna(),holds_count).sum();
      #print(ret)
      samples.append(ret)

    #samples.hist()
    pd.Series(samples).hist()

# %% [markdown]
# # 面對現實(用test_x)

# %%
exp_test_y = model.predict(test_x[usefeatures])
print(exp_test_y[:10])
# Out:
# [[0.925785  ]
#  [0.9272306 ]
#  [0.93693596]
#  [0.9444376 ]
#  [0.9370649 ]
#  [0.9387882 ]
#  [0.9368383 ]
#  [0.9348188 ]
#  [0.932176  ]
#  [0.93215173]]

# %%
exp_test_y = exp_test_y.swapaxes(0, 1)[0]
print(exp_test_y[:10])
# Out:
# [0.925785   0.9272306  0.93693596 0.9444376  0.9370649  0.9387882
#  0.9368383  0.9348188  0.932176   0.93215173]

# %%
exp_test_y = pd.Series(exp_test_y,index=test_x.index)
exp_test_y.plot()
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
showResult(test_price,exp_test_y)
# Out:
# final nan and fee: 33.0
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
showRandomResult(test_price,exp_test_y)

# %%
#所以AI預測股票到底是?

# %%
#回過頭來 為什麼每個人的結果不太一樣？
#我們剛剛其實只訓練一次
#結果還不穩定

# %% [markdown]
# # 模型調整1 : 加入batch,epoches

# %%
#model.compile(loss='binary_crossentropy', optimizer="adam", 
#              batch_size=5000, epochs=200, validation_split=0.2)

# %%
model = Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(len(usefeatures),)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 100)               700
# _________________________________________________________________
# dense_26 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_x,train_y,
          batch_size=50, epochs=50)
# Out:
# Epoch 1/50
# 3398/3398 [==============================] - 0s 25us/step - loss: 0.9919
# Epoch 2/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7827
# Epoch 3/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8181
# Epoch 4/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.8522
# Epoch 5/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.8754
# Epoch 6/50
# 3398/3398 [==============================] - 0s 25us/step - loss: 0.8093
# Epoch 7/50
# 3398/3398 [==============================] - 0s 19us/step - loss: 0.8917
# Epoch 8/50
# 3398/3398 [==============================] - 0s 19us/step - loss: 0.7590
# Epoch 9/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.9997
# Epoch 10/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8087
# Epoch 11/50
# 3398/3398 [==============================] - 0s 22us/step - loss: 0.7480
# Epoch 12/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8031
# Epoch 13/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.8079
# Epoch 14/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.7609
# Epoch 15/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8124
# Epoch 16/50
# 3398/3398 [==============================] - 0s 29us/step - loss: 0.7399
# Epoch 17/50
# 3398/3398 [==============================] - 0s 29us/step - loss: 0.8300
# Epoch 18/50
# 3398/3398 [==============================] - 0s 29us/step - loss: 0.7970
# Epoch 19/50
# 3398/3398 [==============================] - 0s 28us/step - loss: 0.7384
# Epoch 20/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7372
# Epoch 21/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7991
# Epoch 22/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.8629
# Epoch 23/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8559
# Epoch 24/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7584
# Epoch 25/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.7662
# Epoch 26/50
# 3398/3398 [==============================] - 0s 22us/step - loss: 0.7925
# Epoch 27/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7980
# Epoch 28/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7539
# Epoch 29/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.9761
# Epoch 30/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7792
# Epoch 31/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.7559
# Epoch 32/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7479
# Epoch 33/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7552
# Epoch 34/50
# 3398/3398 [==============================] - 0s 20us/step - loss: 0.7642
# Epoch 35/50
# 3398/3398 [==============================] - 0s 22us/step - loss: 0.7299
# Epoch 36/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7336
# Epoch 37/50
# 3398/3398 [==============================] - 0s 26us/step - loss: 0.7541
# Epoch 38/50
# 3398/3398 [==============================] - 0s 29us/step - loss: 0.7988
# Epoch 39/50
# 3398/3398 [==============================] - 0s 28us/step - loss: 0.8347
# Epoch 40/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7148
# Epoch 41/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7332
# Epoch 42/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8444
# Epoch 43/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7125
# Epoch 44/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7424
# Epoch 45/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.8508
# Epoch 46/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7452
# Epoch 47/50
# 3398/3398 [==============================] - 0s 24us/step - loss: 0.7875
# Epoch 48/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7394
# Epoch 49/50
# 3398/3398 [==============================] - 0s 23us/step - loss: 0.7401
# Epoch 50/50
# 3398/3398 [==============================] - 0s 21us/step - loss: 0.7540

# %%
def get_predict_series(inputX,model):
    predict = model.predict(inputX[usefeatures])
    predict = predict.swapaxes(0, 1)[0]
    predict_df = pd.Series(predict,index=inputX.index)
    predict_df.plot()
    plt.show()
    return predict_df

# %%
get_predict_series(train_x,model)
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Date
# 2002-06-19    0.482423
# 2002-06-20    0.475162
# 2002-06-21    0.488843
# 2002-06-24    0.498147
# 2002-06-25    0.498551
#                 ...
# 2015-12-25    0.320261
# 2015-12-28    0.315144
# 2015-12-29    0.327815
# 2015-12-30    0.331071
# 2015-12-31    0.328689
# Length: 3398, dtype: float32

# %%
showResult(train_price,get_predict_series(train_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final 1016.8289179999999 and fee: 300.0

# %%
#一定有人覺得這次妥當了!
showResult(test_price,get_predict_series(test_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final -65.0 and fee: 96.0

# %%
def show_train_history(train_acc,test_acc):
    plt.plot(history.history[train_acc])
    plt.plot(history.history[test_acc])
    plt.title('Train History')
    plt.ylabel(train_acc)
    plt.xlabel('Epochs')
    plt.legend(['train','test'], loc='upper left')
    plt.show()

# %%
show_train_history('acc','val_acc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-587-eb6f00575ffd> in <module>
# ----> 1 show_train_history('acc','val_acc')
#
# <ipython-input-586-9f67b6415399> in show_train_history(train_acc, test_acc)
#       1 def show_train_history(train_acc,test_acc):
# ----> 2     plt.plot(history.history[train_acc])
#       3     plt.plot(history.history[test_acc])
#       4     plt.title('Train History')
#       5     plt.ylabel(train_acc)
#
# KeyError: 'acc'

# %%
#教大家怎看訓練模型訓練好了;validation_split
#https://keras.io/zh/metrics/
#评价函数用于评估当前训练模型的性能。当模型编译后（compile），评价函数应该作为 metrics 的参数来输入。

# %%
model = Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(len(usefeatures),)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
model.summary()

history = model.fit(train_x,train_y,
                    batch_size=50, epochs=50,validation_split=0.2)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 100)               700
# _________________________________________________________________
# dense_29 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2718 samples, validate on 680 samples
# Epoch 1/50
# 2718/2718 [==============================] - 1s 194us/step - loss: 9.1219 - accuracy: 0.4974 - val_loss: 1.2136 - val_accuracy: 0.5588
# Epoch 2/50
# 2718/2718 [==============================] - 0s 28us/step - loss: 1.1064 - accuracy: 0.5004 - val_loss: 0.7215 - val_accuracy: 0.4882
# Epoch 3/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8571 - accuracy: 0.5243 - val_loss: 0.7372 - val_accuracy: 0.4676
# Epoch 4/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8101 - accuracy: 0.5044 - val_loss: 1.0572 - val_accuracy: 0.4971
# Epoch 5/50
# 2718/2718 [==============================] - 0s 27us/step - loss: 1.0588 - accuracy: 0.5063 - val_loss: 1.8950 - val_accuracy: 0.4971
# Epoch 6/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.9245 - accuracy: 0.4941 - val_loss: 0.7558 - val_accuracy: 0.5029
# Epoch 7/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8918 - accuracy: 0.5022 - val_loss: 0.8705 - val_accuracy: 0.4971
# Epoch 8/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8658 - accuracy: 0.5191 - val_loss: 1.6752 - val_accuracy: 0.5029
# Epoch 9/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.9190 - accuracy: 0.5037 - val_loss: 0.7770 - val_accuracy: 0.5029
# Epoch 10/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8165 - accuracy: 0.5110 - val_loss: 0.8599 - val_accuracy: 0.5059
# Epoch 11/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7957 - accuracy: 0.5210 - val_loss: 1.0393 - val_accuracy: 0.4971
# Epoch 12/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7623 - accuracy: 0.5037 - val_loss: 0.7176 - val_accuracy: 0.5044
# Epoch 13/50
# 2718/2718 [==============================] - 0s 25us/step - loss: 0.8673 - accuracy: 0.5059 - val_loss: 1.0629 - val_accuracy: 0.4971
# Epoch 14/50
# 2718/2718 [==============================] - 0s 27us/step - loss: 0.8630 - accuracy: 0.5026 - val_loss: 0.8211 - val_accuracy: 0.5044
# Epoch 15/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0
50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8020 - accuracy: 0.5121 - val_loss: 0.7525 - val_accuracy: 0.4971
# Epoch 37/50
# 2718/2718 [==============================] - 0s 25us/step - loss: 0.7508 - accuracy: 0.5177 - val_loss: 0.9065 - val_accuracy: 0.4971
# Epoch 38/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7835 - accuracy: 0.5125 - val_loss: 0.7135 - val_accuracy: 0.5235
# Epoch 39/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.9473 - accuracy: 0.5107 - val_loss: 1.5889 - val_accuracy: 0.5029
# Epoch 40/50
# 2718/2718 [==============================] - 0s 25us/step - loss: 1.3498 - accuracy: 0.5055 - val_loss: 0.8484 - val_accuracy: 0.5044
# Epoch 41/50
# 2718/2718 [==============================] - 0s 25us/step - loss: 0.8258 - accuracy: 0.5166 - val_loss: 0.7281 - val_accuracy: 0.5074
# Epoch 42/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7987 - accuracy: 0.5147 - val_loss: 0.6941 - val_accuracy: 0.5324
# Epoch 43/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7352 - accuracy: 0.5272 - val_loss: 0.7397 - val_accuracy: 0.5044
# Epoch 44/50
# 2718/2718 [==============================] - 0s 25us/step - loss: 0.9921 - accuracy: 0.5015 - val_loss: 0.6914 - val_accuracy: 0.5735
# Epoch 45/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8188 - accuracy: 0.5276 - val_loss: 0.6986 - val_accuracy: 0.5162
# Epoch 46/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.7733 - accuracy: 0.5243 - val_loss: 0.7884 - val_accuracy: 0.4971
# Epoch 47/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8357 - accuracy: 0.5221 - val_loss: 0.8119 - val_accuracy: 0.5044
# Epoch 48/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8753 - accuracy: 0.5166 - val_loss: 1.2995 - val_accuracy: 0.4971
# Epoch 49/50
# 2718/2718 [==============================] - 0s 27us/step - loss: 0.7560 - accuracy: 0.5357 - val_loss: 0.6907 - val_accuracy: 0.5809
# Epoch 50/50
# 2718/2718 [==============================] - 0s 26us/step - loss: 0.8655 - accuracy: 0.5026 - val_loss: 1.7403 - val_accuracy: 0.4971

# %%
history.history
# Out:
# {'val_loss': [1.213600582059692,
#   0.7215096117819056,
#   0.7372216599829057,
#   1.0571997875676435,
#   1.895048909327563,
#   0.7558132743134218,
#   0.8705203252680161,
#   1.6751677814651937,
#   0.7769746280768338,
#   0.8598572077120051,
#   1.0393465082435047,
#   0.7176496123566347,
#   1.0628774350180346,
#   0.8210613999296638,
#   1.0234078861334746,
#   0.9416968235198189,
#   0.7471636586329516,
#   0.8328274698818431,
#   2.732972024118199,
#   0.8627273002091576,
#   1.2919966043794857,
#   0.7194115843843011,
#   0.7073793604093439,
#   0.8059921124402214,
#   1.4898566077737248,
#   0.9752262147033915,
#   0.851053972454632,
#   0.8179808162591037,
#   1.0395586253965603,
#   0.7698855610454783,
#   0.7194997755920186,
#   1.1458926507655312,
#   0.7247200380353367,
#   0.6819210692363626,
#   1.1019519620081957,
#   0.7525033521301606,
#   0.9064668951665654,
#   0.7135495736318476,
#   1.5888715631821577,
#   0.8484129239531124,
#   0.7281303318107829,
#   0.6940857557689443,
#   0.51655626,
#   0.49668875,
#   0.49852833,
#   0.5143488,
#   0.50441504,
#   0.5183959,
#   0.48896247,
#   0.49705666,
#   0.5264901,
#   0.51655626,
#   0.5121413,
#   0.51766,
#   0.5125092,
#   0.5106696,
#   0.50551873,
#   0.51655626,
#   0.5147167,
#   0.5272259,
#   0.5014717,
#   0.5275938,
#   0.5242826,
#   0.52207506,
#   0.51655626,
#   0.535688,
#   0.5025754]}

# %%
show_train_history('loss','val_loss')

# %%
show_train_history('accuracy','val_accuracy')

# %%
#get_best_model:ModelCheckpoint
#verbose
#https://keras-cn.readthedocs.io/en/latest/models/model/

# %%
get_best_model = keras.callbacks.ModelCheckpoint('nn.mdl', monitor='accuracy')
model = Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(len(usefeatures),)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
model.summary()

history = model.fit(train_x,train_y,
                    batch_size=10, epochs=100,validation_split=0.2,callbacks=[get_best_model],verbose=1)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_49 (Dense)             (None, 100)               700
# _________________________________________________________________
# dense_50 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2718 samples, validate on 680 samples
# Epoch 1/100
# 2718/2718 [==============================] - 1s 322us/step - loss: 2.3002 - accuracy: 0.4901 - val_loss: 0.9552 - val_accuracy: 0.4912
# Epoch 2/100
# 2718/2718 [==============================] - 0s 118us/step - loss: 1.1579 - accuracy: 0.4838 - val_loss: 1.1063 - val_accuracy: 0.4985
# Epoch 3/100
# 2718/2718 [==============================] - 0s 118us/step - loss: 1.3257 - accuracy: 0.5092 - val_loss: 0.8403 - val_accuracy: 0.5529
# Epoch 4/100
# 2718/2718 [==============================] - 0s 118us/step - loss: 1.1710 - accuracy: 0.5147 - val_loss: 1.3775 - val_accuracy: 0.5029
# Epoch 5/100
# 2718/2718 [==============================] - 0s 119us/step - loss: 0.9862 - accuracy: 0.4904 - val_loss: 1.1111 - val_accuracy: 0.4971
# Epoch 6/100
# 2718/2718 [==============================] - 0s 117us/step - loss: 1.0017 - accuracy: 0.5140 - val_loss: 1.4689 - val_accuracy: 0.5029
# Epoch 7/100
# 2718/2718 [==============================] - 0s 169us/step - loss: 0.8204 - accuracy: 0.5140 - val_loss: 1.8679 - val_accuracy: 0.5029
# Epoch 8/100
# 2718/2718 [==============================] - 0s 129us/step - loss: 1.0045 - accuracy: 0.5143 - val_loss: 0.7387 - val_accuracy: 0.5029
# Epoch 9/100
# 2718/2718 [==============================] - 0s 143us/step - loss: 0.8156 - accuracy: 0.4952 - val_loss: 0.8569 - val_accuracy: 0.4971
# Epoch 10/100
# 2718/2718 [==============================] - 0s 126us/step - loss: 0.9384 - accuracy: 0.5059 - val_loss: 0.7451 - val_accuracy: 0.5029
# Epoch 11/100
# 2718/2718 [==============================] - 0s 125us/step - loss: 0.8073 - accuracy: 0.5055 - val_loss: 1.3290 - val_accuracy: 0.4971
# Epoch 12/100
# 2718/2718 [==============================] - 0s 127us/step - loss: 0.8859 - accuracy: 0.5085 - val_loss: 1.4571 - val_accuracy: 0.5029
# Epoch 13/100
step - loss: 0.6932 - accuracy: 0.4993 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 66/100
# 2718/2718 [==============================] - 0s 132us/step - loss: 0.6932 - accuracy: 0.4860 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 67/100
# 2718/2718 [==============================] - 0s 134us/step - loss: 0.6932 - accuracy: 0.4993 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 68/100
# 2718/2718 [==============================] - 0s 146us/step - loss: 0.6932 - accuracy: 0.4838 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 69/100
# 2718/2718 [==============================] - 0s 128us/step - loss: 0.6932 - accuracy: 0.4912 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 70/100
# 2718/2718 [==============================] - 0s 129us/step - loss: 0.6932 - accuracy: 0.4948 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 71/100
# 2718/2718 [==============================] - 0s 134us/step - loss: 0.6932 - accuracy: 0.4934 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 72/100
# 2718/2718 [==============================] - 0s 137us/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 73/100
# 2718/2718 [==============================] - 0s 139us/step - loss: 0.6933 - accuracy: 0.4963 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 74/100
# 2718/2718 [==============================] - 0s 136us/step - loss: 0.6932 - accuracy: 0.4904 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 75/100
# 2718/2718 [==============================] - 0s 137us/step - loss: 0.6932 - accuracy: 0.4956 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 76/100
# 2718/2718 [==============================] - 0s 138us/step - loss: 0.6932 - accuracy: 0.4904 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 77/100
# 2718/2718 [==============================] - 0s 138us/step - loss: 0.6933 - accuracy: 0.4890 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 78/100
# 2718/2718 [==============================] - 0s 140us/step - loss: 0.6932 - accuracy: 0.4971 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 79/100
# 2718/2718 [==============================] - 0s 139us/step - loss: 0.6932 - accuracy: 0.4963 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 80/100
# 2718/2718 [==============================] - 0s 139us/step - loss: 0.6933 - accuracy: 0.4963 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 81/100
# 2718/2718 [==============================] - 0s 140us/step - loss: 0.6932 - accuracy: 0.4904 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 82/100
# 2718/2718 [==============================] - 0s 140us/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 83/100
# 2718/2718 [==============================] - 0s 138us/step - loss: 0.6932 - accuracy: 0.4890 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 84/100
# 2718/2718 [==============================] - 0s 137us/step - loss: 0.6932 - accuracy: 0.4904 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 85/100
# 2718/2718 [==============================] - 0s 143us/step - loss: 0.6932 - accuracy: 0.4860 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 86/100
# 2718/2718 [==============================] - 0s 141us/step - loss: 0.6932 - accuracy: 0.4845 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 87/100
# 2718/2718 [==============================] - 0s 140us/step - loss: 0.6932 - accuracy: 0.4912 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 88/100
# 2718/2718 [==============================] - 0s 140us/step - loss: 0.6932 - accuracy: 0.4860 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 89/100
# 2718/2718 [==============================] - 0s 138us/step - loss: 0.6932 - accuracy: 0.4890 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 90/100
# 2718/2718 [==============================] - 0s 144us/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 91/100
# 2718/2718 [==============================] - 0s 139us/step - loss: 0.6932 - accuracy: 0.4831 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 92/100
# 2718/2718 [==============================] - 0s 139us/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 93/100
# 2718/2718 [==============================] - 0s 142us/step - loss: 0.6932 - accuracy: 0.4978 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 94/100
# 2718/2718 [==============================] - 0s 141us/step - loss: 0.6932 - accuracy: 0.4904 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 95/100
# 2718/2718 [==============================] - 0s 168us/step - loss: 0.6932 - accuracy: 0.4985 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 96/100
# 2718/2718 [==============================] - 0s 177us/step - loss: 0.6932 - accuracy: 0.4845 - val_loss: 0.6925 - val_accuracy: 0.4882
# Epoch 97/100
# 2718/2718 [==============================] - 0s 136us/step - loss: 0.6932 - accuracy: 0.4934 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 98/100
# 2718/2718 [==============================] - 0s 147us/step - loss: 0.6932 - accuracy: 0.4882 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 99/100
# 2718/2718 [==============================] - 0s 135us/step - loss: 0.6932 - accuracy: 0.5007 - val_loss: 0.6925 - val_accuracy: 0.4971
# Epoch 100/100
# 2718/2718 [==============================] - 0s 135us/step - loss: 0.6932 - accuracy: 0.4926 - val_loss: 0.6924 - val_accuracy: 0.4882

# %%
show_train_history('loss','val_loss')

# %%
show_train_history('accuracy','val_accuracy')

# %%
model.load_weights("lstm.mdl")

# %%
showResult(train_price,get_predict_series(train_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final 596.7319320000001 and fee: 246.0

# %%
showResult(test_price,get_predict_series(test_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final nan and fee: 93.0

# %%
#Precion/Recall

# %%
#confusion matrix
#Recall : 選出來且真的上漲的 / 所有上漲的股票
#Precision: 真的上場的 / 預測上漲的
predicts = get_predict_series(test_x,model)
predicts
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# Date
# 2016-01-04    0.499354
# 2016-01-05    0.506963
# 2016-01-06    0.622589
# 2016-01-07    0.742155
# 2016-01-08    0.597923
#                 ...
# 2020-08-17    0.031363
# 2020-08-18    0.056989
# 2020-08-19    0.064098
# 2020-08-20    0.059331
# 2020-08-21    0.088766
# Length: 1127, dtype: float32

# %%
pd.crosstab(np.array(test_y),predicts>predicts.quantile(0.7),colnames=['predict'],rownames=['real'])
# Out:
# predict  False  True
# real
# False      391    162
# True       398    176

# %%
predicts = get_predict_series(train_x,model)
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
pd.crosstab(np.array(train_y),predicts>predicts.quantile(0.7),colnames=['predict'],rownames=['real'])
# Out:
# predict  False  True
# real
# False     1379    320
# True       999    700

# %%
#pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.2-cp37-cp37m-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 941 kB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy>=0.19.1 in /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.5.2)
# Collecting joblib>=0.11
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
#      |████████████████████████████████| 300 kB 21.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.19.1)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=5f2c939966db453fe4d94a52090997a18d378adf3706e29f316403cb3eca8112
#   Stored in directory: /Users/jerry/Library/Caches/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-0.16.0 scikit-learn-0.23.2 sklearn-0.0 threadpoolctl-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import precision_recall_curve

# %%
precisions, recalls, thresholds = precision_recall_curve(test_y, exp_test_y)

pd.DataFrame({
    'precisions':precisions[:-1],
    'recalls':recalls[:-1],
}, index=thresholds).plot()


#Recall : 選出來且真的上漲的 / 所有上漲的股票
#Precision: 真的上場的 / 預測上漲的
#畫圖說明

#Precision: 門檻值越大越不會預測會上漲 所以大到1就變成0了
#Recall : 門檻值越小代表你預測全部人都會上漲 所以當=0 當然所有有上漲的都有抓到
#股票比較care precision
# Out:
# [1.         0.99825784 0.99825784 ... 0.         0.         0.        ]

# %%
test_y
# Out:
# Date
# 2016-01-04    False
# 2016-01-05    False
# 2016-01-06    False
# 2016-01-07     True
# 2016-01-08    False
#               ...
# 2020-08-17    False
# 2020-08-18    False
# 2020-08-19    False
# 2020-08-20    False
# 2020-08-21    False
# Name: Return, Length: 1127, dtype: bool

# %% [markdown]
# # 結果分析(準確率）

# %%
#benchmarkt
(dataset_test["Return"]>0).sum() / len(dataset_test)
# Out:
# 0.5093167701863354

# %%
#上面代表我亂猜成功率

# %% [markdown]
# # 如何更好？

# %%
#換週期(原本預測三天後
#加入更多indicator
#測試不同組合indicator
#門檻值
#正規化
#物理力量
#模型加深
#換模型(LSTM)

# %%
dataset.describe()
# Out:
#             sma_60       sma_20        sma_5            k            d  \
# count  4525.000000  4525.000000  4525.000000  4525.000000  4525.000000
# mean    314.526550   316.454700   317.311933    53.253316    53.167475
# std     105.844507   109.680750   111.153241    25.633789    24.200984
# min     128.910500   124.541700   120.907400     6.727577     8.864621
# 25%     232.883333   237.539650   238.286603    30.338161    32.077687
# 50%     301.125000   304.900000   304.762396    54.700855    53.558753
# 75%     386.425000   389.466197   392.149402    78.055799    76.586467
# max     600.700000   692.500000   721.000000    92.352216    90.100671
#
#                rsi        Price
# count  4525.000000  4525.000000
# mean     51.300340   317.507109
# std      11.865264   111.500741
# min      16.789236   116.214996
# 25%      43.192563   237.500000
# 50%      51.838170   304.500000
# 75%      59.413906   391.500000
# max      87.203931   732.000000

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

dataset_scaled = ss.fit_transform(dataset)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=dataset.columns, index=dataset.index)
dataset_scaled['Return'] = dataset['Return']
dataset_scaled['Price'] = dataset['Price']
dataset_scaled.describe()
# Out:
#              sma_60        sma_20         sma_5             k             d  \
# count  4.525000e+03  4.525000e+03  4.525000e+03  4.525000e+03  4.525000e+03
# mean   2.638037e-16 -1.758691e-16  2.386795e-16 -1.821502e-16  1.256208e-16
# std    1.000111e+00  1.000111e+00  1.000111e+00  1.000111e+00  1.000111e+00
# min   -1.753861e+00 -1.749935e+00 -1.767166e+00 -1.815217e+00 -1.830824e+00
# 25%   -7.714358e-01 -7.195772e-01 -7.110370e-01 -8.940421e-01 -8.715397e-01
# 50%   -1.266294e-01 -1.053601e-01 -1.129155e-01  5.647622e-02  1.616965e-02
# 75%    6.793588e-01  6.657464e-01  6.733563e-01  9.676769e-01  9.677946e-01
# max    2.704014e+00  3.428923e+00  3.632217e+00  1.525456e+00  1.526272e+00
#
#                 rsi        Price
# count  4.525000e+03  4525.000000
# mean  -3.643004e-16   317.507109
# std    1.000111e+00   111.500741
# min   -2.908904e+00   116.214996
# 25%   -6.833959e-01   237.500000
# 50%    4.533316e-02   304.500000
# 75%    6.838840e-01   391.500000
# max    3.026276e+00   732.000000

# %%
dataset
# Out:
#                 sma_60      sma_20       sma_5          k          d  \
# Date
# 2002-06-19  202.883783  164.559151  152.158603  48.282006  78.448562
# 2002-06-20  201.039049  163.312051  152.227402  46.792790  77.709663
# 2002-06-21  199.359516  161.928901  153.390600  45.416323  76.947186
# 2002-06-24  197.719766  160.784901  154.962399  44.068558  76.162122
# 2002-06-25  195.983249  159.674850  155.919400  42.679049  75.354269
# ...                ...         ...         ...        ...        ...
# 2020-08-17  591.225000  692.500000  684.400000  91.666219  74.513389
# 2020-08-18  594.141667  691.500000  669.200000  91.468973  75.325665
# 2020-08-19  596.625000  688.750000  655.000000  91.098885  76.115780
# 2020-08-20  598.375000  683.150000  631.200000  90.579138  76.880481
# 2020-08-21  600.700000  679.600000  616.000000  90.155635  77.616203
#
#                   rsi  Return       Price
# Date
# 2002-06-19  31.738284    True  149.292007
# 2002-06-20  35.979458    True  153.044998
# 2002-06-21  41.670005   False  158.516998
# 2002-06-24  43.363226   False  160.225998
# 2002-06-25  42.048730   False  158.516998
# ...               ...     ...         ...
# 2020-08-17  55.524987   False  685.000000
# 2020-08-18  39.190404   False  617.000000
# 2020-08-19  37.782178   False  609.000000
# 2020-08-20  31.151991   False  565.000000
# 2020-08-21  41.029944   False  604.000000
#
# [4525 rows x 8 columns]

# %%
dataset_scaled
# Out:
#               sma_60    sma_20     sma_5         k         d       rsi  \
# Date
# 2002-06-19 -1.054897 -1.385041 -1.485981 -0.193957  1.044746 -1.648865
# 2002-06-20 -1.072328 -1.396413 -1.485362 -0.252059  1.014211 -1.291381
# 2002-06-21 -1.088198 -1.409025 -1.474896 -0.305763  0.982701 -0.811731
# 2002-06-24 -1.103692 -1.419456 -1.460753 -0.358346  0.950258 -0.669011
# 2002-06-25 -1.120100 -1.429578 -1.452143 -0.412558  0.916874 -0.779808
# ...              ...       ...       ...       ...       ...       ...
# 2020-08-17  2.614486  3.428923  3.302905  1.498692  0.882124  0.356091
# 2020-08-18  2.642046  3.419805  3.166142  1.490996  0.915692 -1.020734
# 2020-08-19  2.665510  3.394729  3.038376  1.476557  0.948343 -1.139432
# 2020-08-20  2.682046  3.343666  2.824234  1.456279  0.979945 -1.698283
# 2020-08-21  2.704014  3.311296  2.687471  1.439756  1.010349 -0.865681
#
#             Return       Price
# Date
# 2002-06-19    True  149.292007
# 2002-06-20    True  153.044998
# 2002-06-21   False  158.516998
# 2002-06-24   False  160.225998
# 2002-06-25   False  158.516998
# ...            ...         ...
# 2020-08-17   False  685.000000
# 2020-08-18   False  617.000000
# 2020-08-19   False  609.000000
# 2020-08-20   False  565.000000
# 2020-08-21   False  604.000000
#
# [4525 rows x 8 columns]

# %%
dataset_train = dataset_scaled[:'2016']
dataset_test = dataset_scaled['2016':]
train_price = dataset_scaled["Price"][:'2016']
test_price = dataset_scaled["Price"]['2016':]
train_x = dataset_train[usefeatures]
train_y = dataset_train['Return']
test_x = dataset_test[usefeatures]
test_y = dataset_test['Return']

# %%
model = Sequential()
model.add(layers.Dense(100, activation='relu', input_shape=(len(usefeatures),)))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])
model.summary()

history = model.fit(train_x,train_y,
                    batch_size=50, epochs=50,validation_split=0.2,verbose=0)
print('ok')
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_58 (Dense)             (None, 100)               700
# _________________________________________________________________
# dense_59 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_60 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 10,901
# Trainable params: 10,901
# Non-trainable params: 0
# _________________________________________________________________
# ok

# %%
showResult(train_price,get_predict_series(train_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final 2341.314146999998 and fee: 750.0

# %%
showResult(test_price,get_predict_series(test_x,model))
# Out:
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# /Users/jerry/opt/anaconda3/envs/DLCourse/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# final 48.0 and fee: 132.0

# %%
# 排序
# df.sort_index(inplace=True)

# %%
#How many indicators?
talib.get_functions()
# Out:
# ['HT_DCPERIOD',
#  'HT_DCPHASE',
#  'HT_PHASOR',
#  'HT_SINE',
#  'HT_TRENDMODE',
#  'ADD',
#  'DIV',
#  'MAX',
#  'MAXINDEX',
#  'MIN',
#  'MININDEX',
#  'MINMAX',
#  'MINMAXINDEX',
#  'MULT',
#  'SUB',
#  'SUM',
#  'ACOS',
#  'ASIN',
#  'ATAN',
#  'CEIL',
#  'COS',
#  'COSH',
#  'EXP',
#  'FLOOR',
#  'LN',
#  'LOG10',
#  'SIN',
#  'SINH',
#  'SQRT',
#  'TAN',
#  'TANH',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROON',
#  'AROONOSC',
#  'BOP',
#  'CCI',
#  'CMO',
#  'DX',
#  'MACD',
#  'MACDEXT',
#  'MACDFIX',
#  'MFI',
#  'MINUS_DI',
#  'MINUS_DM',
#  'MOM',
#  'PLUS_DI',
#  'PLUS_DM',
#  'PPO',
#  'ROC',
#  'ROCP',
#  'ROCR',
#  'ROCR100',
#  'RSI',
#  'STOCH',
#  'STOCHF',
#  'STOCHRSI',
#  'TRIX',
#  'ULTOSC',
#  'WILLR',
#  'BBANDS',
#  'DEMA',
#  'EMA',
#  'HT_TRENDLINE',
#  'KAMA',
#  'MA',
#  'MAMA',
#  'MAVP',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'SMA',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'CDL2CROWS',
#  'CDL3BLACKCROWS',
#  'CDL3INSIDE',
#  'CDL3LINESTRIKE',
#  'CDL3OUTSIDE',
#  'CDL3STARSINSOUTH',
#  'CDL3WHITESOLDIERS',
#  'CDLABANDONEDBABY',
#  'CDLADVANCEBLOCK',
#  'CDLBELTHOLD',
#  'CDLBREAKAWAY',
#  'CDLCLOSINGMARUBOZU',
#  'CDLCONCEALBABYSWALL',
#  'CDLCOUNTERATTACK',
#  'CDLDARKCLOUDCOVER',
#  'CDLDOJI',
#  'CDLDOJISTAR',
#  'CDLDRAGONFLYDOJI',
#  'CDLENGULFING',
#  'CDLEVENINGDOJISTAR',
#  'CDLEVENINGSTAR',
#  'CDLGAPSIDESIDEWHITE',
#  'CDLGRAVESTONEDOJI',
#  'CDLHAMMER',
#  'CDLHANGINGMAN',
#  'CDLHARAMI',
#  'CDLHARAMICROSS',
#  'CDLHIGHWAVE',
#  'CDLHIKKAKE',
#  'CDLHIKKAKEMOD',
#  'CDLHOMINGPIGEON',
#  'CDLIDENTICAL3CROWS',
#  'CDLINNECK',
#  'CDLINVERTEDHAMMER',
#  'CDLKICKING',
#  'CDLKICKINGBYLENGTH',
#  'CDLLADDERBOTTOM',
#  'CDLLONGLEGGEDDOJI',
#  'CDLLONGLINE',
#  'CDLMARUBOZU',
#  'CDLMATCHINGLOW',
#  'CDLMATHOLD',
#  'CDLMORNINGDOJISTAR',
#  'CDLMORNINGSTAR',
#  'CDLONNECK',
#  'CDLPIERCING',
#  'CDLRICKSHAWMAN',
#  'CDLRISEFALL3METHODS',
#  'CDLSEPARATINGLINES',
#  'CDLSHOOTINGSTAR',
#  'CDLSHORTLINE',
#  'CDLSPINNINGTOP',
#  'CDLSTALLEDPATTERN',
#  'CDLSTICKSANDWICH',
#  'CDLTAKURI',
#  'CDLTASUKIGAP',
#  'CDLTHRUSTING',
#  'CDLTRISTAR',
#  'CDLUNIQUE3RIVER',
#  'CDLUPSIDEGAP2CROWS',
#  'CDLXSIDEGAP3METHODS',
#  'AVGPRICE',
#  'MEDPRICE',
#  'TYPPRICE',
#  'WCLPRICE',
#  'BETA',
#  'CORREL',
#  'LINEARREG',
#  'LINEARREG_ANGLE',
#  'LINEARREG_INTERCEPT',
#  'LINEARREG_SLOPE',
#  'STDDEV',
#  'TSF',
#  'VAR',
#  'ATR',
#  'NATR',
#  'TRANGE',
#  'AD',
#  'ADOSC',
#  'OBV']
